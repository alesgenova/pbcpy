# %%
import numpy as np
from pbcpy.grid import Grid_Space as gs, Grid_Function as gf, Grid_Function_Reciprocal as gfr
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
at = np.identity(3)

# %%
nr = [50,50,50]
grid = gs(at, nr)
gf_func = gf(grid)
alpha=0.1

# %%
dens = gf_func.gaussian(alpha=alpha,center_array=[0.5,0.5,0.5])
plt.plot(dens.values[:,25,25])
plt.show()

# %%
kernel_values = grid.reciprocal_grid.square_dist_values()
kernel_func = gfr(grid_space=grid, griddata_3d=kernel_values)
in_kernel_func = kernel_func.invert()

# %%
plt.plot(in_kernel_func.values[:,0,0])
plt.show()

# %%
energyPot = dens.energy_potential(kernel=in_kernel_func,a=1.0,c=4*np.pi)

# %%
#print(energyPot.values)
plt.plot(energyPot.values[:,25,25])
plt.plot(dens.values[:,25,25])
plt.show()
